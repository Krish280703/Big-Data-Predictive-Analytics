# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

def dist_summary(dist_data, dist_name):
    # Convert distribution data to a pandas Series
    dist_series = pd.Series(dist_data)

    # Plot histogram
    dist_series.hist()
    plt.title(f'Histogram of {dist_name}')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.show()

    # Return summary statistics
    summary_stats = dist_series.describe()
    return summary_stats


def sim_normal(nums,mean,standard_deviation):
    for n in nums:
        normal_data = np.random.normal(loc = mean, scale=standard_deviation,size = n)
        # Create a distribution name based on the size 'n'
        dist_name = f'Normal(n={n}, mean={mean}, std_dev={standard_deviation})'
        
        # Use the dist_summary function to display summary statistics
        summary_stats = dist_summary(normal_data, dist_name)
        print(f'\nSummary Statistics for {dist_name}:\n{summary_stats}\n{"="*40}')
        

# Example Usage:
# Assuming you have a distribution named 'example_dist' with data
# Replace 'example_dist_data' with your actual distribution data
example_dist_data = [1, 2, 2, 3, 3, 3, 4, 4, 5]
example_dist_name = 'example_dist'


result_summary = dist_summary(example_dist_data, example_dist_name)
print(result_summary)
# Out:
# count    9.000000
# mean     3.000000
# std      1.224745
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
mean = 0
standard_deviation = 1
nums = [50, 100, 200]

sim_normal(nums, your_mean, standard_deviation)
# Out:
# Summary Statistics for Normal(n=50, mean=0, std_dev=1):
# count    50.000000
# mean     -0.301043
# std       0.909558
# min      -1.829863
# 25%      -0.961255
# 50%      -0.293157
# 75%       0.292979
# max       1.602241
# dtype: float64
# ...
# Summary Statistics for Normal(n=100, mean=0, std_dev=1):
# count    100.000000
# mean      -0.068151
# std        1.033314
# min       -2.449617
# 25%       -0.718500
# 50%       -0.100886
# 75%        0.488361
# max        2.848697
# dtype: float64
# ...
# Summary Statistics for Normal(n=200, mean=0, std_dev=1):
# count    200.000000
# mean      -0.025845
# std        0.962441
# min       -2.942312
# 25%       -0.696063
# 50%       -0.012867
# 75%        0.637552
# max        2.719953
# dtype: float64
# ...

# %%
mean = 600
standard_deviation = 30
nums = [50, 100, 200]

sim_normal(nums, mean, standard_deviation)
# Out:
# Summary Statistics for Normal(n=50, mean=600, std_dev=30):
# count     50.000000
# mean     606.177861
# std       34.848896
# min      539.613834
# 25%      586.061602
# 50%      607.403608
# 75%      621.773083
# max      708.063472
# dtype: float64
# ...
# Summary Statistics for Normal(n=100, mean=600, std_dev=30):
# count    100.000000
# mean     601.214356
# std       29.923889
# min      535.680960
# 25%      582.313015
# 50%      600.011857
# 75%      621.421679
# max      690.485351
# dtype: float64
# ...
# Summary Statistics for Normal(n=200, mean=600, std_dev=30):
# count    200.000000
# mean     594.474710
# std       30.040030
# min      516.671974
# 25%      572.536860
# 50%      592.516819
# 75%      616.134829
# max      672.801311
# dtype: float64
# ...

# %% [markdown]
# # Exercise 2

# %%
def sim_poisson(nums, mean):
    for n in nums:
        # Generate random values from Poisson distribution
        poisson_data = np.random.poisson(lam=mean, size=n)
        
        # Create a distribution name based on the size 'n'
        dist_name = f'Poisson(n={n}, mean={mean})'
        
        # Use the dist_summary function to display summary statistics
        summary_stats = dist_summary(poisson_data, dist_name)
        print(f'\nSummary Statistics for {dist_name}:\n{summary_stats}\n{"="*40}')
        
        # Plot histogram
        plt.hist(poisson_data, bins=20, alpha=0.7, label=dist_name)

    plt.title('Comparison of Normal and Poisson Distributions')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# %%
mean = 600
nums = [100000, 1000000]

sim_poisson(nums, mean)
# Out:
# Summary Statistics for Poisson(n=100000, mean=600):
# count    100000.000000
# mean        599.934400
# std          24.451403
# min         502.000000
# 25%         583.000000
# 50%         600.000000
# 75%         616.000000
# max         703.000000
# dtype: float64
# ...
# Summary Statistics for Poisson(n=1000000, mean=600):
# count    1000000.000000
# mean         599.945934
# std           24.494492
# min          484.000000
# 25%          583.000000
# 50%          600.000000
# 75%          616.000000
# max          721.000000
# dtype: float64
# ...
